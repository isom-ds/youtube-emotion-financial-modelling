# %% [markdown]
# # Financial Modelling
# ## Preliminary Analysis - Graphs

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from modules.finance.visualisation import *

# Display and plotting options
pd.options.display.float_format = "{:.4f}".format
plt.rcParams["figure.figsize"] = (10, 4)

# Analysis window
START_DATE = "2025-01-01"
END_DATE = "2025-05-31"

DATA_FILE = "data/financial_returns_with_epi.parquet"

# %%
returns = pd.read_parquet(DATA_FILE)

# %%
epi_returns_plot(returns, figsize=(20, 20), font_base=25)
